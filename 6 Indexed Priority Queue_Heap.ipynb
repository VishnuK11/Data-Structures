# %% [markdown]
# # Indexed Priority Queue

# %%
#
#     Incomplete. Needs work
#

# Need to implement swapping when adding new elements for pm and im. Otherwise O(n) instead of O(logn)
# Create a Binary Heap, ie. every element has a maximum of two children
# Index priority queue - with binary heap
# Value, Keyindex, heap_position <-> position map, inverse map
# Can't handle duplicate and duplicate based errors yet.

# %%
import random
from math import log

# %%
class indexed_priority_queue(binary_heap):
    def __init__(self):
        ipq=binary_heap()
        self.master_name=[]
        self.master_value=[]
        self.master_keyindex=[]
        self.ki_v_pair=[] # key_index, value pair
        self.pm=[]
        self.im=[]
        self.size=0 # Size updates after new. Size is number of elements. ALso the index of new element to add
        
    def add_ipq(self,name,value):
        self.master_name.append(name)
        self.master_value.append(value)
#         self.master_keyindex.append(self.size)
        
        ipq.add_heap(val)
        for i in range(self.size):
            self.im[i]= master_value.index(ipq.heap_value[i]) #At heap position 2, which key index is present
        for i in range(self.size):
            self.pm[self.size]=ipq.heap_value.index(master_value[i])  #Where is KI 0 in the heap. Where is Vlaue of KI[0
        self.size+=1

class binary_heap():
    def __init__(self):
        self.heap_value,self.heap_index=[[],[]]
        #self.heap=[self.heap_value,self.heap_index]
        self.capacity=1
        self.size=0
        #Indexed:
        
        
    def add_heap(self,new_value): 
        self.heap_value.append(new_value)
        self.heap_index.append(self.size+1) # Index starts with 1
        self.size+=1
        while self.size>self.capacity:
            self.capacity=2*self.capacity
        self.sortit()
            
    def remove(self,old_value): 
        self.heap_value.remove(old_value)
        self.heap_index.remove(self.size)
        self.size+=-1
        print("Item removed",old_value)
        self.printall()
        
    def peek(self):
        print("Peek top value is :", self.heap_value[self.size-1])
        return self.heap_value[self.size-1]
    
    def printall(self):
        count=0
        binary=0
        for i in range(self.size):
            temp=self.heap_value
            print(temp[i]," ", end ="")
            count+=1
            if count>=(2**binary):
                binary+=1
                count=0
                print("\n", end ="")
            
        print("\nTotal No of items is:", self.size)
        
    def swim(self, index): 
        
        current=index
        parent=int(index/2 -0.5)
        
#         print("Index:",index," Parent:",parent)
#         print("Index value:",self.heap_value[index]," Parent value:",self.heap_value[parent])
        change=False
        
        level=int(log(self.size+1,2))
        for limit in range(level):
            
            while self.heap_value[parent]>self.heap_value[index]:
                print("Swiming Up Note")
                change=True
                #(swap parent and index)
                temp=self.heap_value[parent]
                self.heap_value[parent]=self.heap_value[index]
                self.heap_value[index]=temp

                # Reassign parent index 
                index=int(index/2-0.5)
                parent=int(index/2-0.5)
                
                if log(index+1,2)<=limit:
                    break
            index=current
            parent=int(index/2 -0.5)
            
        if change:
            self.printall()
        
    def sink(self, index): 
        # This function needs work
        current=index
        child1=int(2*index+1)
        child2=int(2*index+2)
        change=False
        
        if child1>=self.size:
            return None
        if child1<self.size and child2>=self.size:
            child2=child1
        #child=int(2*index, 2*index+1)
#         print("Index:",index," child:",child1," ",child2)
#         print("Index value:",self.heap_value[index]," child value:",self.heap_value[child1],self.heap_value[child2])
        
        level=int(log(self.size+1,2))
        for limit in range(level):
            
            while self.heap_value[index]>self.heap_value[child1] or self.heap_value[index]>self.heap_value[child2] :
                print("Sink Up Note")
                change=True
                
                if self.heap_value[index]>self.heap_value[child1] and self.heap_value[index]>self.heap_value[child2]:
                    if self.heap_value[child1]<=self.heap_value[child2]:
                        child=child1
                    else:
                        child=child2                    
                elif self.heap_value[index]>self.heap_value[child1]:
                     child=child1
                elif self.heap_value[index]>self.heap_value[child2]:
                     child=child2
                        
                 #(swap parent and index)
                temp=self.heap_value[child]
                self.heap_value[child]=self.heap_value[index]
                self.heap_value[index]=temp
            
                 # Reassign parent index 
                index=child
                child1=int(2*index+1)
                child2=int(2*index+2)
                if child1 >=self.size:
                    break
                elif child2 >=self.size:
                    child2=child1              
                self.printall()
                
            index=current
            child1=int(2*index+1)
            child2=int(2*index+2)
            if child1>self.size and child2>self.size:
                break
            if child1<self.size and child2>=self.size:
                child2=child1
               
        if change:
            self.printall()
        
    def sortit(self):
        for index in range(self.size-1,0,-1):
            self.swim(index)
        for index in range(0,self.size):
            self.sink(index)
        #Create a map for keeping track of elements
        #heapify cs.umd.edu

# %%
new_heap=binary_heap()
for i in range(8):
    new_heap.add_heap(random.randint(0, 20))
new_heap.printall()

#new_heap.remove(3)
# new_heap.add_heap(-1)
# Out:
# Swiming Up Note
# Swiming Up Note
# 5
# 14  20
# 14
# Total No of items is: 4
# Swiming Up Note
# 5
# 8  20
# 14  14
# Total No of items is: 5
# Swiming Up Note
# 5
# 8  8
# 14  14  20
# Total No of items is: 6
# 5
# 8  8
# 14  14  20  16
# 20
# Total No of items is: 8

# %%
new_heap.sortit()
# Out:
# Index: 7  Parent: 3
# Index value: 3  Parent value: 4
# Swiming Up Note
# Swiming Up Note
# Swiming Up Note
# Swiming Up Note
# Swiming Up Note
# Swiming Up Note
# 3
# 4  16
# 15  0  1  6
# 20
# Total No of items is: 8
# Index: 6  Parent: 2
# Index value: 6  Parent value: 16
# Swiming Up Note
# 3
# 4  6
# 15  0  1  16
# 20
# Total No of items is: 8
# Index: 5  Parent: 2
# Index value: 1  Parent value: 6
# Swiming Up Note
# Swiming Up Note
# 1
# 4  3
# 15  0  6  16
# 20
# Total No of items is: 8
# Index: 4  Parent: 1
# Index value: 0  Parent value: 4
# Swiming Up Note
# Swiming Up Note
# 0
# 1  3
# 15  4  6  16
# 20
# Total No of items is: 8
# Index: 3  Parent: 1
# Index value: 15  Parent value: 1
# Index: 2  Parent: 0
# Index value: 3  Parent value: 0
# Index: 1  Parent: 0
# Index value: 1  Parent value: 0
# Index: 0  child: 1   2
# Index value: 0  child value: 1 3
# Index: 1  child: 3   4
# Index value: 1  child value: 15 4
# Index: 2  child: 5   6
# Index value: 3  child value: 6 16
# Index: 3  child: 7   7
# Index value: 15  child value: 20 20

# %%
new_heap.printall()
# Out:
# -1
# 5  0
# 8  10  0
# Total No of items is: 6
